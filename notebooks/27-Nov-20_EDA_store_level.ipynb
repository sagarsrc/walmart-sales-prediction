# %% [markdown]
# # Initialize

# %%
# set path for source files
import sys
src_files_path = "../src/"
if src_files_path not in sys.path:
    sys.path.append(src_files_path)


# required libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns



# custom scripts
import data
import utils
import plots

data_prep = data.DataPrepare("../data")

util_handle = utils.Utils()
plot_handle = plots.Plot()
# Out:
# Your data root path : ../data

# %%
data_melted = data_prep.prepare_data()

df_stm = data_melted['sales_train_melted']
print(df_stm.shape)
df_stm.head(3)
# Out:
# Loading ../data/processed/data_melted.bin
# (58327370, 6)
#                    id  day        item_id    dept_id store_id  sales
# 0  HOBBIES_1_001_CA_1  d_1  HOBBIES_1_001  HOBBIES_1     CA_1      0
# 1  HOBBIES_1_002_CA_1  d_1  HOBBIES_1_002  HOBBIES_1     CA_1      0
# 2  HOBBIES_1_003_CA_1  d_1  HOBBIES_1_003  HOBBIES_1     CA_1      0

# %%
df_cal = data_melted['calendar']

# %% [markdown]
# # Total sales per store

# %%
plot_handle.num_sales_per_store(df_stm)

# %% [markdown]
# # Daily sales for each store

# %%
plot_handle.view_daily_sales_per_store(df_stm, df_cal, window=90)
# Out:
# As the data is highly uneven and it is difficult to distinguish between graphs
# We will do smoothing of daily sales of each store with window of 90 days

# %% [markdown]
# # Calendar heatmap for store CA_1

# %%
e = plot_handle.view_calplot_heatmap(df_stm, df_cal, store_id='CA_1', window=None)
# Out:
# Calendar heatmap for sales of store CA_1
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
e
# Out:
# date
# 2011-01-29    4337.0
# 2011-01-30    4155.0
# 2011-01-31    2816.0
# 2011-02-01    3051.0
# 2011-02-02    2630.0
#                ...
# 2016-04-20    3722.0
# 2016-04-21    3709.0
# 2016-04-22    4387.0
# 2016-04-23    5577.0
# 2016-04-24    6113.0
# Name: sales, Length: 1913, dtype: float64
